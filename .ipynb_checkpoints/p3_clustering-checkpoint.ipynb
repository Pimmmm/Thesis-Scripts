# %%
# %matplotlib inline

import os
import numpy as np
import pickle
import random
import pandas as pd
import glob
import matplotlib.pyplot as plt
import heapq
import torch
import cv2

from tqdm.notebook import tqdm
from PIL import Image
from sklearn.cluster import MiniBatchKMeans
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.manifold import TSNE
from sklearn.preprocessing import normalize
from torchvision import transforms

# %%
os.getcwd()
# Out:
# '/raid/home/arend036/msc_pim/Thesis-Scripts'

# %%
concept_score = pd.read_csv('../data/concept_scores.csv', index_col = 0)

# %%
son_votes = pd.read_csv('../data/son_votes.csv', index_col = 0)

# %%
SON_VECTOR_PATH = '../data/son_tensors.pickle'

# %% [markdown]
# ## Cluster Scenic-Or-Not images

# %% [markdown]
# Load all tensors of the Scenic-Or-Not dataset as a dictionary. The dictionary contains the following structure: <br>
# img_index : [image_name, image_path, image_tensor]

# %%
with open(SON_VECTOR_PATH, 'rb') as handle:
    son_acts = pickle.load(handle)

# %%
len(son_acts.keys())
# Out:
# 212102

# %% [markdown]
# Compute the matrix of activations from all SoN images.

# %%
if os.path.exists('../data/son_matrix.npy'):
    son_matrix = np.load('../data/son_matrix.npy')

else:
    cuda = torch.device('cuda')
    son_matrix = torch.zeros(len(son_acts.keys()), son_acts[list(son_acts.keys())[0]][2].shape[0]).cuda

    for i in tqdm(range(len(son_acts.keys()))):
        img_tensor = son_acts[list(son_acts.keys())[i]][2].unsqueeze(0).cuda()
        son_matrix[i] = img_tensor

    son_matrix = np.asarray(son_matrix.to(device='cpu'))
    np.save('../data/son_matrix.npy', son_matrix)

# %% [markdown]
# This image is not in the dataset and thus the index should be not be in the dictionary. For confirmation:

# %%
'52642' in son_acts.keys()
# Out:
# False

# %% [markdown]
# Apply a minibatch k-means clustering to cluster all images into 50 groups. A mini-batch clustering is applied as the sample size is about 212100 which requires high computational time. Several amount of clusters have been tried, at around 50 no 'structure' can be seen in the clusters. The clusters are visualized with t-SNE.

# %%
son_matrix_norm = normalize(son_matrix)

# %%
np.random.seed(42)
num_clusters = 50
kmeans = MiniBatchKMeans(n_clusters = num_clusters, batch_size = 100, init = 'k-means++', max_iter = 2000)

kmeans.fit(son_matrix_norm)
clusters = kmeans.cluster_centers_

# %%
np.save('../data/son_clusters_50_2048.npy', clusters)

# %%
tsne = TSNE(n_components=2, random_state=0)
X_2d = tsne.fit_transform(clusters)

# %% [markdown]
# Each cluster is visualized in a 2D space using t-SNE. Each cluster is also annotated to make it easier to check which clusters are neighbouring. Which is useful when looking at the concepts representing the clusters

# %%
cluster_labels = list(range(50))

plt.scatter(X_2d[:,0], X_2d[:,1])
for i, txt in enumerate(cluster_labels):
    plt.annotate(str(txt), (X_2d[:,0][i], X_2d[:,1][i]))

# %% [markdown]
# For each cluster the average concepts scores are calculated. The concepts which show an average concept score larger than 0 should represent the cluster.

# %%
# every image is assigned to a cluster, the assignment is stored as a label
labels = kmeans.labels_
np.save('../data/image_cluster_labels.npy', labels)

# %%
labels.shape
# Out:
# (212102,)

# %%
cluster_dict = {}
for i in tqdm(range(num_clusters)):
    concept_score_cluster = concept_score.loc[(labels == i),:]
    mean_score = concept_score_cluster.mean()
    scenicness_score = round(son_votes.loc[(labels==i),'Average'].mean(),2)
    cluster_dict['cluster_' + str(i)] = [mean_score[mean_score > 0].sort_values(ascending=False), scenicness_score]
# Out:
# HBox(children=(IntProgress(value=0, max=50), HTML(value='')))

# %%
for key in cluster_dict.keys():
    print(key, ": scenicness score: ", cluster_dict[key][1])
    print(cluster_dict[key][0])
    print('\n')
# Out:
# cluster_0 : scenicness score:  3.76
# tree                   573.042931
# bush                   456.771779
# embankment             300.398421
# fence                  209.552665
# earth                  144.648371
# field                  129.984944
# bleachers-outdoor-s    117.324370
# path                    31.186116
# dtype: float64
#
#
# cluster_1 : scenicness score:  2.46
# building    564.502314
# sky         361.960891
# tree         83.975636
# dtype: float64
#
#
# cluster_2 : scenicness score:  3.34
# building                 968.591678
# tree                     819.164830
# sky                      430.997549
# sidewalk                 369.068132
# roof                     247.067943
# castle-s                  73.493412
# observatory-outdoor-s     19.706165
# dtype: float64
#
#
# cluster_3 : scenicness score:  4.53
# rock                969.364674
# tree                798.813205
# aqueduct-s          763.373387
# bridge-s            692.920575
# bridge              619.317984
# bush                492.583721
# trestle             287.775710
# water               180.173782
# embankment          158.001572
# canal-natural-s     101.827092
# drainage_ditch-s     13.900405
# field                13.116735
# pillar                2.432676
# dtype: float64
#
#
# cluster_4 : scenicness score:  4.45
# field                        1224.180058
# park-s                        860.498742
# tree                          754.982878
# bush                          683.076501
# grass                         584.616326
# field-cultivated-s            566.682628
# yard-s                        375.357408
# lawn-s                        361.268662
# golf_course-s                 351.522504
# sky                           250.747389
# drainage_ditch-s              206.287283
# pasture-s                     181.397529
# flower                        138.430262
# hayfield-s                     98.269381
# path                           80.326020
# fairway-s                      75.713716
# badminton_court-outdoor-s      68.465427
# roundabout-s                   66.861863
# irrigation_ditch-s             57.079615
# orchard-s                      54.150508
# ground                         41.953538
# dtype: float64
#
#
# cluster_5 : scenicness score:  4.49
# tree                  1520.276905
# yard-s                 706.117952
# earth                  395.681244
# path                   392.615475
# japanese_garden-s      379.119374
# embankment             378.854060
# hedge                  358.552071
# forest_path-s          340.457219
# drainage_ditch-s       334.070961
# park-s                 295.146186
# bush                   283.213080
# fence                  204.990410
# grass                  193.233426
# plant                  189.824733
# dirt_track-s           155.727433
# botanical_garden-s     154.149093
# field                  104.466225
# rock                    62.577961
# dtype: float64
#
#
# cluster_6 : scenicness score:  4.61
# tree                  1473.309602
# field                 1024.576279
# bush                   911.873214
# yard-s                 801.757293
# drainage_ditch-s       590.846017
# grass                  524.061241
# japanese_garden-s      509.654724
# park-s                 429.192096
# lawn-s                 421.759271
# earth                  397.626411
# field-cultivated-s     383.875146
# botanical_garden-s     376.121585
# orchard-s              363.499029
# marsh-s                360.406495
# hedge                  278.396392
# irrigation_ditch-s     274.344976
# dirt_track-s           244.648112
# embankment             227.528646
# path                   169.566460
# plant                  161.457851
# water                  118.641237
# forest_path-s          106.951629
# vegetable_garden-s      82.429031
# flower                  79.192862
# pasture-s               38.189869
# trestle                  4.076104
# dtype: float64
#
#
# cluster_7 : scenicness score:  4.54
# field                 1338.340130
# bush                  1106.207332
# field-cultivated-s     843.958169
# flower                 688.385480
# tree                   592.069361
# lawn-s                 523.752780
# wheat_field-s          401.068187
# grass                  374.878777
# drainage_ditch-s       311.783259
# irrigation_ditch-s     286.784432
# yard-s                 194.512000
# plant                  159.865279
# hayfield-s             147.665860
# orchard-s              140.111979
# marsh-s                125.257202
# park-s                 111.037460
# field-wild-s            57.185665
# water                   28.621255
# roundabout-s            27.512680
# field_road-s            10.733182
# dtype: float64
#
#
# cluster_8 : scenicness score:  4.44
# tree                     885.164651
# building                 498.065036
# abbey-s                  361.564141
# sky                      214.438204
# castle-s                 194.571817
# observatory-outdoor-s    168.632541
# grass                    139.352051
# mansion-s                 24.715743
# dtype: float64
#
#
# cluster_9 : scenicness score:  4.07
# building                 1005.699035
# roof                      967.453674
# abbey-s                   940.619552
# tree                      771.569099
# mansion-s                 693.508119
# sky                       488.917321
# pillar                    392.766887
# cloister-outdoor-s        385.762075
# mission-s                 318.849584
# castle-s                  219.146967
# church-outdoor-s          211.638774
# guardhouse-s              208.246734
# dacha-s                   187.908806
# house                     183.994956
# observatory-outdoor-s     158.072834
# windmill-s                133.022035
# granary-s                 114.595907
# cloud                      51.156830
# earth                      50.737272
# sidewalk                   39.373064
# farm-s                     16.697846
# grass                       1.878119
# dtype: float64
#
#
# cluster_10 : scenicness score:  5.03
# rock                  1089.705967
# tree                  1008.240084
# water                  412.957473
# japanese_garden-s      342.739893
# embankment             296.895577
# earth                  288.112019
# creek-s                282.132039
# plant                  278.847201
# bush                   244.787750
# trestle                215.449307
# forest_path-s          186.000005
# dirt_track-s           166.723697
# botanical_garden-s     158.092795
# vegetable_garden-s      56.998581
# potholed                42.136732
# drainage_ditch-s        28.306698
# fence                    7.867470
# dtype: float64
#
#
# cluster_11 : scenicness score:  5.31
# field                 1206.117281
# bush                   829.172776
# embankment             754.530299
# dirt_track-s           492.574143
# marsh-s                466.004889
# pasture-s              426.516942
# drainage_ditch-s       410.119930
# moor-s                 402.060097
# earth                  393.514312
# field_road-s           347.266495
# butte-s                303.929034
# irrigation_ditch-s     290.310255
# desert-sand-s          279.415914
# hill                   251.688639
# mountain               237.933466
# valley-s               221.242744
# path                   166.606704
# field-cultivated-s     148.212718
# grass                  141.823906
# tree                   104.946227
# hayfield-s              67.748170
# field-wild-s            64.535567
# flower                  17.842531
# dtype: float64
#
#
# cluster_12 : scenicness score:  4.74
# grass        761.066600
# fence        367.483276
# pasture-s    312.413376
# sheep        248.695051
# tree         247.917676
# ground       226.270836
# flower        94.468646
# torso         93.113810
# earth         92.582257
# dtype: float64
#
#
# cluster_13 : scenicness score:  4.31
# tree                   939.491220
# fence                  823.693220
# path                   648.587082
# field                  599.536784
# bush                   575.317654
# bleachers-outdoor-s    573.174269
# embankment             556.389920
# earth                  263.015320
# cemetery-s             223.434782
# pasture-s              187.043135
# grass                  179.143538
# irrigation_ditch-s     170.424373
# hedge                  164.238367
# dtype: float64
#
#
# cluster_14 : scenicness score:  6.58
# rock                1058.295317
# mountain            1049.538144
# cliff                970.170743
# earth                736.221279
# canyon-s             511.066746
# fjord-s              464.251243
# valley-s             419.988154
# embankment           292.660504
# hill                 243.045423
# pasture-s            177.734692
# mountain-s           135.464980
# mountain_path-s      110.896756
# grass                109.707894
# mountain_snowy-s      69.376490
# valley                63.317914
# cactus                57.350669
# butte-s               52.656495
# badlands-s            42.193366
# potholed              40.030050
# sky                   36.728071
# moor-s                 8.694099
# waterfall-fan-s        5.059827
# dtype: float64
#
#
# cluster_15 : scenicness score:  4.06
# tree        1584.318959
# park-s      1182.215530
# yard-s       690.931149
# grass        655.594541
# field        419.245270
# hedge        380.896523
# bush         357.064429
# sky          260.191328
# building     221.862398
# lawn-s       153.306227
# path         145.881500
# earth         50.306546
# dtype: float64
#
#
# cluster_16 : scenicness score:  4.52
# tree                  1187.023176
# field                 1135.633620
# bush                  1083.194610
# field-cultivated-s     396.194813
# marsh-s                389.912166
# dirt_track-s           328.412282
# irrigation_ditch-s     261.699642
# drainage_ditch-s       180.485343
# earth                  149.176317
# hayfield-s              95.030348
# ground                  79.566129
# field-wild-s            44.003990
# yard-s                  38.033559
# field_road-s            34.089039
# grass                    8.530520
# dtype: float64
#
#
# cluster_17 : scenicness score:  2.21
# building        1423.825882
# sidewalk         986.560834
# road             918.019959
# street-s         879.698048
# car              664.629581
# sky              538.557481
# tree             468.171841
# roundabout-s     284.671620
# signboard        220.467036
# dtype: float64
#
#
# cluster_18 : scenicness score:  4.54
# tree        613.538642
# bush        523.268666
# bridge      367.494353
# bridge-s    256.715929
# water       219.517718
# rock        166.145647
# lake         67.932644
# earth        14.804633
# dtype: float64
#
#
# cluster_19 : scenicness score:  4.25
# roof                     1481.584546
# mansion-s                1066.036748
# farm-s                    988.851163
# dacha-s                   966.133645
# abbey-s                   961.390201
# cabin-outdoor-s           922.946901
# building                  877.792950
# hovel                     819.731820
# house                     788.472885
# mission-s                 687.351460
# military_hut-s            665.164504
# tree                      644.691643
# granary-s                 643.821960
# earth                     610.084402
# sky                       607.074387
# garage-outdoor-s          513.485211
# windmill-s                510.301830
# hut-s                     482.272377
# cloud                     397.528432
# cottage-s                 395.826276
# guardhouse-s              390.122712
# barn-s                    375.412853
# observatory-outdoor-s     354.342522
# cloister-outdoor-s        348.369198
# attic-s                   212.255616
# castle-s                  208.829592
# embankment                187.296185
# grass                     173.630399
# industrial_park-s         159.309237
# ranch_house-s             159.087931
# church-outdoor-s          146.822501
# windmill                  137.999090
# sink                       76.298076
# diner-outdoor-s            67.842709
# hill                       59.945787
# donjon-s                   47.117156
# house-s                    40.933853
# pasture-s                  28.031643
# boathouse-s                23.368767
# butte-s                    22.688958
# driveway-s                  6.460546
# dtype: float64
#
#
# cluster_20 : scenicness score:  5.76
# earth               709.734249
# pasture-s           703.436785
# field               652.841938
# grass               634.829896
# embankment          602.086576
# mountain            580.275165
# hill                374.296206
# drainage_ditch-s    358.457009
# rock                325.613017
# valley-s            285.842898
# bush                257.777571
# moor-s              219.433145
# dirt_track-s        174.574279
# valley              165.782718
# butte-s             164.933825
# path                127.942497
# cliff                95.643290
# canyon-s             86.657356
# marsh-s              43.105400
# cactus               36.677213
# desert-sand-s        24.971206
# dtype: float64
#
#
# cluster_21 : scenicness score:  3.62
# tree                     857.424324
# field                    553.475980
# building                 469.227082
# sky                      427.194131
# earth                    361.053513
# grass                    293.562449
# bush                     254.730323
# farm-s                   252.003924
# industrial_park-s        163.166472
# observatory-outdoor-s    112.696387
# embankment                68.370150
# house                     53.912266
# military_hut-s            53.650015
# hovel                     52.716398
# dtype: float64
#
#
# cluster_22 : scenicness score:  6.88
# cliff                955.686052
# rock                 647.782140
# sea                  645.691599
# sand                 558.464890
# sky                  515.920678
# fjord-s              491.846204
# mountain             425.704020
# canyon-s             300.698661
# lagoon-s             239.312080
# butte-s              226.947056
# bush                 205.355902
# coast-s              128.241338
# earth                124.975931
# aquatic_theater-s     65.181598
# land                  63.922759
# islet-s               46.566461
# lake                   7.547421
# dtype: float64
#
#
# cluster_23 : scenicness score:  6.82
# mountain            957.066149
# valley-s            710.966075
# earth               597.488902
# field               529.840152
# hill                464.823445
# pasture-s           435.195815
# valley              394.885264
# canyon-s            344.635912
# grass               289.004072
# mountain-s          286.896490
# moor-s              247.164495
# fjord-s             240.126120
# embankment          235.802701
# dirt_track-s        215.741279
# butte-s             181.369913
# rock                155.491793
# mountain_snowy-s    131.521996
# slope               118.057297
# desert-sand-s       113.114726
# mountain_path-s     104.469912
# bush                104.316617
# cliff                63.152571
# cactus               51.777234
# hill-s               47.258559
# dtype: float64
#
#
# cluster_24 : scenicness score:  4.67
# tree                  1760.349526
# field                  687.402103
# bush                   652.796418
# yard-s                 409.197711
# earth                  307.036275
# park-s                 290.235149
# sky                    241.325314
# marsh-s                194.247497
# japanese_garden-s      138.327377
# building                91.617103
# grass                   56.376853
# field-cultivated-s      50.501248
# drainage_ditch-s        32.710465
# path                     0.370337
# dtype: float64
#
#
# cluster_25 : scenicness score:  4.98
# tree                          1957.768170
# earth                          874.599135
# yard-s                         709.722454
# forest_path-s                  579.881607
# ski_slope-s                    531.474128
# japanese_garden-s              473.026151
# embankment                     419.616233
# fence                          394.020053
# water                          310.330052
# botanical_garden-s             303.795489
# park-s                         164.668155
# trestle                        115.695712
# vegetable_garden-s             113.038097
# bog-s                           89.693166
# forest-needleleaf-s             71.951246
# hedge                           68.327719
# orchard-s                       44.605147
# flight_of_stairs-natural-s      40.254062
# forest_road-s                   21.699274
# lawn-s                           2.484271
# dtype: float64
#
#
# cluster_26 : scenicness score:  5.56
# field                 1024.487620
# bush                   672.294287
# moor-s                 327.843556
# earth                  210.494989
# sky                    208.539249
# dirt_track-s           199.394485
# valley-s               199.266365
# pasture-s              198.509101
# embankment             150.693970
# butte-s                132.566466
# tree                   132.190709
# grass                  128.351852
# desert-sand-s          106.807524
# mountain                29.434529
# field-wild-s            28.291611
# marsh-s                 26.101990
# irrigation_ditch-s      17.905271
# path                     8.522554
# valley                   6.487737
# hill                     3.583304
# dtype: float64
#
#
# cluster_27 : scenicness score:  2.9
# building            1324.873239
# roof                1035.151177
# sidewalk             619.643257
# house-s              556.462884
# sky                  502.679406
# tree                 482.896072
# diner-outdoor-s      297.781410
# car                  242.102545
# earth                184.789237
# road                 176.180962
# mansion-s            129.835626
# garage-outdoor-s      56.803947
# guardhouse-s          37.640948
# dtype: float64
#
#
# cluster_28 : scenicness score:  3.38
# tree          994.138155
# earth         244.496694
# building      221.590277
# path          165.451056
# yard-s         94.593902
# embankment     94.401531
# fence          89.180285
# bush            3.196990
# dtype: float64
#
#
# cluster_29 : scenicness score:  4.24
# field     727.762777
# tree      533.732011
# bush      408.736707
# grass     398.020026
# park-s    147.335799
# sky        12.129860
# dtype: float64
#
#
# cluster_30 : scenicness score:  5.52
# tree                  1209.659328
# bush                  1196.640162
# water                 1036.087726
# lake                   932.736652
# marsh-s                690.435758
# river                  530.438368
# cloud                  332.179022
# river-s                304.440525
# lake-natural-s         274.466701
# bayou-s                273.392334
# irrigation_ditch-s     221.684023
# field                  214.329671
# sky                    189.751459
# fjord-s                109.436251
# golf_course-s           88.541263
# dtype: float64
#
#
# cluster_31 : scenicness score:  4.85
# tree                          1865.569135
# yard-s                         925.966468
# japanese_garden-s              729.774141
# earth                          584.182876
# vegetable_garden-s             565.538935
# forest_path-s                  517.812340
# botanical_garden-s             506.789183
# embankment                     492.522362
# fence                          468.233034
# dirt_track-s                   380.344754
# drainage_ditch-s               329.149542
# plant                          311.612001
# rock                           279.705072
# park-s                         274.427772
# water                          242.350630
# trestle                        218.610716
# orchard-s                      179.832338
# fibrous                        128.272167
# bush                           113.192047
# hedge                          111.107271
# grass                           89.980001
# creek-s                         88.207828
# marsh-s                         84.106537
# field                           80.386329
# ski_slope-s                     77.941968
# lawn-s                          68.876388
# flight_of_stairs-natural-s      38.863835
# path                            29.438777
# dtype: float64
#
#
# cluster_32 : scenicness score:  4.36
# field                 1333.998674
# bush                   954.800105
# field-cultivated-s     668.603377
# tree                   562.319413
# marsh-s                487.084579
# field_road-s           466.804325
# hayfield-s             437.464476
# field-wild-s           434.073627
# desert-sand-s          309.721229
# irrigation_ditch-s     290.619410
# ground                 254.553890
# dirt_track-s           243.882429
# embankment             225.653016
# moor-s                 184.481025
# butte-s                173.115836
# drainage_ditch-s       149.698203
# wheat_field-s           90.970704
# path                    32.278513
# flower                  16.154570
# dtype: float64
#
#
# cluster_33 : scenicness score:  5.58
# sand         1319.921433
# sky           661.122557
# ground        407.313321
# beach-s       383.485881
# water         375.608892
# bush          272.048505
# sea           243.102541
# coast-s       224.584477
# moor-s        104.793916
# sandbar-s      93.772500
# estuary-s      61.092200
# dtype: float64
#
#
# cluster_34 : scenicness score:  4.6
# tree                  1163.083357
# earth                  851.402929
# bush                   783.481970
# field                  676.969200
# embankment             430.406931
# drainage_ditch-s       414.842149
# marsh-s                377.472224
# grass                  243.082231
# japanese_garden-s      217.710329
# mountain               200.621288
# ski_slope-s            187.960047
# water                  173.486799
# sky                    141.851173
# forest_path-s          130.080575
# yard-s                 118.595644
# botanical_garden-s     116.893783
# forest                  81.688673
# trestle                 49.985492
# irrigation_ditch-s      25.456339
# dirt_track-s            21.658825
# dtype: float64
#
#
# cluster_35 : scenicness score:  3.06
# tree                984.582625
# road                844.341446
# building            774.671625
# access_road-s       660.313861
# street-s            564.692683
# roundabout-s        542.523487
# sky                 448.084651
# car                 433.231958
# bush                418.406916
# highway-s           188.253945
# embankment          161.783909
# forest_road-s       153.693580
# sidewalk             91.694110
# drainage_ditch-s     84.233677
# ground               62.097766
# path                 22.655782
# earth                 4.588065
# dtype: float64
#
#
# cluster_36 : scenicness score:  5.83
# snow            872.752620
# earth           775.808395
# sky             666.255477
# ski_resort-s    390.805516
# ski_slope-s     376.524969
# cloud           336.713041
# mountain        183.059928
# fjord-s         147.847059
# tree            141.795643
# potholed         39.319456
# dtype: float64
#
#
# cluster_37 : scenicness score:  2.93
# coach                  1280.411708
# train                   697.018168
# bridge                  341.295748
# track                   323.353906
# railway                 290.622606
# bleachers-outdoor-s     249.127554
# railroad train          105.933752
# ground                   90.870345
# dtype: float64
#
#
# cluster_38 : scenicness score:  3.12
# sky              711.257476
# tree             634.178900
# roundabout-s     571.412389
# building         549.101020
# bush             534.487034
# road             426.155628
# access_road-s    115.066372
# ground            86.271021
# street-s          12.332438
# dtype: float64
#
#
# cluster_39 : scenicness score:  3.13
# tree                 1082.847894
# building             1073.035765
# sky                   666.736596
# roof                  334.149474
# earth                 329.273832
# sidewalk              324.525267
# road                  284.065234
# industrial_park-s     122.496599
# house-s                81.086573
# yard-s                 66.492237
# car                    43.096317
# parking_lot-s          29.657052
# dtype: float64
#
#
# cluster_40 : scenicness score:  3.68
# roof                     897.109139
# tree                     749.727265
# building                 681.408522
# earth                    640.646669
# hovel                    471.631453
# house                    427.893439
# military_hut-s           394.696841
# sky                      308.540096
# farm-s                   267.504816
# cabin-outdoor-s          267.387856
# dacha-s                  238.578051
# industrial_park-s        216.604413
# observatory-outdoor-s    148.332139
# mansion-s                130.679239
# house-s                   59.786818
# yard-s                    20.912556
# driveway-s                19.252964
# granary-s                 15.427866
# garage-outdoor-s          12.979579
# embankment                 5.255566
# guardhouse-s               3.354756
# dtype: float64
#
#
# cluster_41 : scenicness score:  5.31
# water                601.471734
# sky                  567.206261
# bush                 394.438460
# aquatic_theater-s    391.341444
# boat                 384.748786
# sea                  354.343389
# lake                 180.406354
# fjord-s              162.553195
# sand                  50.732117
# dtype: float64
#
#
# cluster_42 : scenicness score:  4.4
# field                 1157.327897
# bush                  1063.768847
# path                   554.885086
# tree                   551.132709
# drainage_ditch-s       523.051814
# embankment             496.608982
# irrigation_ditch-s     395.061880
# grass                  330.304273
# roundabout-s           198.646281
# sky                    192.833112
# field-cultivated-s     173.132152
# earth                  153.030413
# plant                   92.441292
# marsh-s                 70.349902
# dirt_track-s            50.353803
# moor-s                  12.086592
# dtype: float64
#
#
# cluster_43 : scenicness score:  5.22
# rock               1425.113459
# mountain           1115.211031
# badlands-s          589.149694
# cliff               564.447447
# potholed            534.281153
# canyon-s            490.226541
# dirt_track-s        479.433696
# butte-s             424.036981
# earth               420.081240
# fjord-s             244.476372
# badlands            117.907359
# mountain_path-s     107.201165
# valley-s             87.809546
# cavern-indoor-s      73.617372
# smeared              60.391250
# hill                 53.519226
# embankment           48.658325
# dtype: float64
#
#
# cluster_44 : scenicness score:  4.41
# bush                  1152.726965
# tree                  1083.455178
# field                 1054.163690
# marsh-s                950.134851
# drainage_ditch-s       560.479741
# embankment             500.594869
# field-cultivated-s     445.803063
# earth                  422.839168
# irrigation_ditch-s     414.156907
# field_road-s           397.013330
# dirt_track-s           376.740743
# water                  276.950781
# mountain               229.463792
# ground                 209.490578
# japanese_garden-s      192.119019
# orchard-s              169.507601
# field-wild-s           160.786371
# yard-s                 152.141785
# butte-s                149.935386
# trestle                137.936634
# hayfield-s             124.950295
# pasture-s              104.379258
# forest                  93.375185
# farm-s                  66.197897
# flower                  46.351643
# desert-sand-s           42.878301
# fibrous                 40.757180
# hill                    35.771343
# moor-s                  27.393737
# dtype: float64
#
#
# cluster_45 : scenicness score:  5.4
# path                607.267856
# earth               463.264745
# bush                458.584103
# field               432.174624
# rock                399.364005
# embankment          387.818113
# cemetery-s          291.376428
# grass               164.366326
# pasture-s            92.454017
# drainage_ditch-s     47.005384
# dtype: float64
#
#
# cluster_46 : scenicness score:  5.35
# field                 895.346224
# mountain              714.025462
# bush                  663.482033
# desert-sand-s         592.269140
# moor-s                545.582012
# marsh-s               484.766750
# butte-s               449.667337
# dirt_track-s          436.313726
# earth                 424.839505
# embankment            354.594387
# hill                  352.447169
# pasture-s             329.625141
# tree                  312.196337
# field-wild-s          288.577235
# field_road-s          243.984033
# drainage_ditch-s      219.331687
# ground                180.675783
# hayfield-s             92.218033
# irrigation_ditch-s     82.659322
# valley-s               81.191167
# dtype: float64
#
#
# cluster_47 : scenicness score:  3.99
# tree                  1263.446305
# bush                   895.012012
# field                  472.949183
# path                   391.160615
# drainage_ditch-s       385.673129
# embankment             314.263925
# sky                    297.991795
# yard-s                 287.797879
# earth                  284.325984
# access_road-s          253.965671
# marsh-s                234.944004
# ground                 229.699708
# building               152.135836
# grass                  146.987343
# road                   144.163145
# irrigation_ditch-s     110.986282
# roundabout-s            72.307314
# dirt_track-s            66.923395
# park-s                  40.932019
# forest_road-s           16.928731
# hedge                    6.995328
# dtype: float64
#
#
# cluster_48 : scenicness score:  5.91
# rock        345.810074
# moor-s      335.993635
# sand        312.083214
# earth       283.346018
# sky         267.910401
# mountain    260.080394
# bush        192.429109
# land         79.463415
# fjord-s      72.055526
# butte-s      42.235826
# cloud        22.733927
# marsh-s      11.705981
# potholed      9.556694
# dtype: float64
#
#
# cluster_49 : scenicness score:  5.68
# field                 902.983803
# mountain              782.483297
# bush                  646.607116
# earth                 464.753439
# rock                  377.393687
# tree                  356.896393
# drainage_ditch-s      338.814012
# dirt_track-s          275.645182
# valley-s              275.089269
# embankment            261.905046
# grass                 235.841703
# japanese_garden-s     154.861040
# hill                  124.226289
# botanical_garden-s    123.734084
# pasture-s              75.764726
# plant                  57.612394
# fjord-s                35.183994
# irrigation_ditch-s     35.102418
# dtype: float64

# %% [markdown]
# The concepts related to each cluster show what kind of images can be found in these clusters. There is still overlap between several clusters especially in relation to concepts like 'tree', 'earth', 'field', 'bush'. These are concepts which can be present in almost every image. However, several interesting clusters are also determined:
# - cluster 9: related to buildings
# - cluster 12: related to pasture
# - cluster 14: related to areas with mountains, hills and long views
# - cluster 17: related to city environment
# - cluster 22: related to coastal areas
# - cluster 36: related to snow
# - cluster 37: related to transportation
# - cluster 41: related to water

# %% [markdown]
# Define a cluster of interest:

# %%
cluster_num = 3

# %%
img_in_cluster = list(labels == cluster_num) # get boolean array of image is specified cluster
img_cluster_idx = [t for t, value in enumerate(img_in_cluster) if value] #get the index value of every image in the cluster
img_cluster_idx = [t+1 if t >= 201047 else t+1 if t>= 52642 else t for t in img_cluster_idx]

# %% [markdown]
# Extract the paths to the images and randomly sample a specified number of images

# %%
paths = []
for img_idx in tqdm(img_cluster_idx):
    paths.append(son_acts[str(img_idx)][1])

cluster_random_sample = random.sample(paths, 49)
# Out:
# HBox(children=(IntProgress(value=0, max=1232), HTML(value='')))

# %% [markdown]
# Plot the images

# %%
fig = plt.figure(figsize=(12,12))
ax = [fig.add_subplot(7, 7, i+1) for i in range(len(cluster_random_sample))]

for idx, a in enumerate(ax):
    img = plt.imread(paths[idx])
    a.axis('off')
    a.imshow(img)

fig.subplots_adjust(wspace=0, hspace=0)
plt.show()

# %% [markdown]
# Every cluster has a cluster centroid described as a vector. The most similar images 9 to the cluster centroid of interest are displayed

# %%
# extract cluster centroid vector
cluster_centroid = clusters[cluster_num]
cluster_centroid = cluster_centroid.reshape(1,2048)

# %%
# extract image vectors assigned to the cluster
cluster_imgs = son_matrix_norm[labels == cluster_num, :]

# %%
cluster_imgs.shape
# Out:
# (1232, 2048)

# %%
# calculate the cosine similarity between the cluster centroid and the cluster images. Transpose the vector to a row vector
cluster_similar_imgs = cosine_similarity(cluster_centroid, son_matrix_norm).T

# %%
cluster_similar_imgs
# Out:
# array([[0.6919598 ],
#        [0.79134935],
#        [0.7260342 ],
#        ...,
#        [0.8318554 ],
#        [0.68875265],
#        [0.6333028 ]], dtype=float32)

# %%
# extract the indices of the 9 most similar images
similar_idxs = heapq.nlargest(3, range(len(cluster_similar_imgs)), cluster_similar_imgs.take)
similar_idxs = [t+2 if t >= 201047 else t+1 if t>= 52642 else t for t in similar_idxs]

# %%
sim_paths = []
for sim_idx in similar_idxs:
    sim_paths.append(son_acts[str(sim_idx)][1])

# %%
img_transform = transforms.Compose([transforms.CenterCrop(400)])

# %%
from IPython.display import display
oriimage = Image.open(sim_paths[1])

crop_image = img_transform(oriimage)
plt.imshow(np.asarray(crop_image))
# oriimage.show()

# %%
fig = plt.figure(figsize=(9,9))
ax = [fig.add_subplot(1, 3, i+1) for i in range(len(similar_idxs))]

# img_list = []

for idx, a in enumerate(ax):
    img = Image.open(sim_paths[idx])
    crop_img = img_transform(img)
    crop_img = np.asarray(crop_img)
#     img_list.append(crop_img)
    a.axis('off')
    a.imshow(crop_img)

fig.subplots_adjust(wspace=0, hspace=0)
# fig.subplots_adjust(bottom=0.26, top=0.74)
plt.show()
